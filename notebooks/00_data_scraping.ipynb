# %% [markdown]
# # EBI Scraping
# In this notebook, we will download metadata and the results of functional analyses from several studies related to human skin microbiome.
# The notebook utilises [MGnify API toolkit](https://github.com/EBI-Metagenomics/emg-toolkit).
#
# ## Table of contents
# 1. [Study dataset](#introduction)
# 2. [Example of downloading one study set](#example1)
# 3. [Example of downloading multiple study set](#example2)

# %%
import pandas as pd
from mg_toolkit.metadata import OriginalMetadata
from mg_toolkit.bulk_download import BulkDownloader
import os, sys
from requests import get
from pathlib import Path

# %%
def fetch_metadata(study_accession):
    '''
    Retrieve original metadata of a given study accession. Download a csv file.
    '''
    outfile = f'../tables/{study_accession}/{study_accession}_sample.csv'
    if os.path.exists(outfile):
        pass
    else:
        try:
            os.mkdir(f'../tables/{study_accession}')
        except FileExistsError:
            pass
        try:
            metadata = pd.DataFrame(OriginalMetadata(study_accession).fetch_metadata()).T
            metadata.to_csv(outfile)
        except ConnectionError:
            print("Unexpected error:", sys.exc_info()[0])
    return

# %%
def stats_downloader(study_accession, pipeline, result_group='statistics'):
    '''
    Retrieve the list of downloadables item for a given study. Download a tsv file.
    '''
    outdir = Path('../tables')
    outfile = outdir / study_accession / f'v{pipeline}_{study_accession}_metadata.tsv'
    if os.path.exists(outfile):
        pass
    else:
        try:
            os.mkdir(outdir / study_accession)
        except FileExistsError:
            pass
        data = BulkDownloader(study_accession, outdir, pipeline, result_group)
        data.run()
        try:
            os.rename(outdir / study_accession / f'{study_accession}_metadata.tsv', outfile)
        except FileNotFoundError:
            pass
    return

# %%
def read_statistics(study_accession, pipeline):
    '''
    Helper function to read a big csv file into pandas dataframe.
    '''
    indir = Path('../tables')
    infile = indir / study_accession / f'v{pipeline}_{study_accession}_metadata.tsv'

    # https://stackoverflow.com/questions/41303246/error-tokenizing-data-c-error-out-of-memory-pandas-python-large-file-csv/41303449
    try:
        mylist = []

        for chunk in pd.read_csv(infile, sep='\t', chunksize=20000):
            mylist.append(chunk)

        big_data = pd.concat(mylist, axis= 0)
        del mylist
    except FileNotFoundError:
        big_data = "Pipeline version " + pipeline + ' is not available' #+ str(sys.exc_info()[0])
    return big_data

# %%
def item_downloader(accession, df):
    '''
    Download items listed in the dataframe from the stats_downloader function. It is recommended to filter the dataframe for files of interest. 
    '''
    for i in df.index:
        outdir = Path('../data') / accession / str(df.loc[i, 'pipeline_version']) / str(df.loc[i, 'group_type']).replace(' ', '_').lower()
        outfile = outdir / df.loc[i, 'name']
        #print(outfile)
        if os.path.exists(outfile):
            pass
        else:
            try:
                os.makedirs(outdir)
            except FileExistsError:
                pass
            url = df.loc[i, 'download_url']
            html = get(url)
            r = get(url, allow_redirects=True)
            open(outfile, 'wb').write(r.content)
            print(outfile)
    return

# %% [markdown]
# ## Study dataset <a name="introduction"></a>
# The list of studies were downloaded as csv file using https://www.ebi.ac.uk/metagenomics/search, with host-associated:human and skin as keyword. The csv file is available at [../tables/search_download.csv]('../data/search_download.csv').
#
# Here, the dataset was filtered to exclude third party annotation (TPA) and datasets with know access problem (to be defined).

# %%
df_studies = pd.read_csv('../tables/search_download.csv')

# filter for third party annotation
mask = [num for num, i in enumerate(df_studies.creation_date) if not 'TPA' in i]
df_studies = df_studies.loc[mask, :]

# filter to exclude hard to access studies
df_studies = df_studies[~df_studies.loc[:, 'ENA_PROJECT'].isin(['PRJNA46333', 'PRJNA554499', 'PRJNA395539', 'PRJEB16723'])]
df_studies
# Out:
#     ENA_PROJECT METAGENOMICS_ANALYSES METAGENOMICS_SAMPLES  \
# 0    PRJEB26427          MGYA00381378           ERS2431659
# 1   PRJNA314604          MGYA00497609           SRS1333647
# 2   PRJNA281366          MGYA00381322            SRS927195
# 4   PRJNA277905          MGYA00376956            SRS892108
# 6    PRJEB10133          MGYA00010238            ERS805761
# 7    PRJEB10295          MGYA00010281            ERS809858
# 10   PRJEB14627          MGYA00556025           ERS1225501
# 14    PRJEB5728          MGYA00415113            ERS414654
# 16    PRJEB5758          MGYA00440312            ERS418163
# 18  PRJNA269787          MGYA00421513            SRS786731
# 21  PRJNA413474            SRS2570847                 Skin
# 22   PRJEB17696          MGYA00140568           ERS1474891
# 23  PRJNA278873          MGYA00028386            SRS879308
# 24  PRJNA266117             SRS741522                 Skin
# 26   PRJEB20777          MGYA00130873           ERS1719848
# 27   PRJEB14948          MGYA00069429           ERS1269857
# 28  PRJNA435265          MGYA00380818           SRS2987431
# 30  PRJNA415710            SRS2629139                 Skin
# 31    PRJEB5727          MGYA00385253            ERS413070
#
#                                            biome_name  \
# 0                                                Skin
# 1                                                Skin
# 2                                                Skin
# 4                                                Skin
# 6                                                Skin
# 7                                                Skin
# 10                                               Skin
# 14                                               Skin
# 16                                               Skin
# 18                                               Skin
# 21                        The University of Hong Kong
# 22                                               Skin
# 23                                               Skin
# 24                         University of Pennsylvania
# 26                                               Skin
# 27                                               Skin
# 28                                               Skin
# 30  Indian Institute of Science Education and Rese...
# 31                                               Skin
#
#                                           centre_name  \
# 0                     P&G Singapore Innovation Center
# 1                          NYU Langone Medical Center
# 2                                University of Trento
# 4                       Genome Institute of Singapore
# 6                             GSTT BRC Bioinformatics
# 7                    LEIDEN UNIVERSITY MEDICAL CENTER
# 10                             UNIVERSITY OF HELSINKI
# 14                                      CCME-COLORADO
# 16                                      CCME-COLORADO
# 18                                   Fudan University
# 21  A metagenomic study on the skin microbiome aft...
# 22                               The ithree institute
# 23              Indiana University School of Medicine
# 24  Viruses can impact microbiome structure and fu...
# 26                                              LSHTM
# 27                     Institute of tropical medicine
# 28                                        Mount Sinai
# 30  The study aimed at exploring the scalp microbi...
# 31                                      CCME-COLORADO
#
#                                         creation_date            description  \
# 0   Metagenomics samples of multiple skin sites (u...  metagenomics_projects
# 1   To characterize the diversity of cutaneous mic...  metagenomics_projects
# 2    Skin shotgun metagenomes from psoriasis patients  metagenomics_projects
# 4                               Human Skin Microbiome  metagenomics_projects
# 6   These samples are selections from a larger coh...  metagenomics_projects
# 7   Whole genome sequencing of metagenomes extract...  metagenomics_projects
# 10  The skin protects from outer threats and this ...  metagenomics_projects
# 14  Forehead skin samples from Flores_SMP for subm...  metagenomics_projects
# 16           Skin samples from human 3D metabolic map  metagenomics_projects
# 18  The variability in skin microbial communities ...  metagenomics_projects
# 21                              metagenomics_projects           MGYS00005424
# 22  Background: Type II diabetes is a chronic heal...  metagenomics_projects
# 23  The aim of this project was to investigate the...  metagenomics_projects
# 24                              metagenomics_projects           MGYS00005384
# 26  Microgravity induces physiological decondition...  metagenomics_projects
# 27  Background: Buruli ulcer (BU) is an infectious...  metagenomics_projects
# 28  In this study, we compare the both sequencing ...  metagenomics_projects
# 30                              metagenomics_projects           MGYS00005574
# 31  palm samples from Flores_SMP for submission to...  metagenomics_projects
#
#                                         domain_source  \
# 0                                        MGYS00005102
# 1                                        MGYS00005212
# 2                                        MGYS00005101
# 4                                        MGYS00005037
# 6                                        MGYS00000518
# 7                                        MGYS00000520
# 10                                       MGYS00005533
# 14                                       MGYS00005156
# 16                                       MGYS00005232
# 18                                       MGYS00005238
# 21                                MTR skin microbiome
# 22                                       MGYS00002072
# 23                                       MGYS00000605
# 24  Human skin bacterial metagenome and Virome Met...
# 26                                       MGYS00001818
# 27                                       MGYS00001187
# 28                                       MGYS00005098
# 30  Elucidating the dandruff and non-dandruff scal...
# 31                                       MGYS00005135
#
#                                                    id  last_modification_date  \
# 0   Understanding the microbial basis of body odor...                     NaN
# 1   Body site is a more determinant factor than hu...                     NaN
# 2                                    Skin metagenomes                     NaN
# 4                    Human Skin Microbiome Metagenome                     NaN
# 6   These samples are selections from a larger coh...                     NaN
# 7   Whole genome sequencing of metagenomes extract...                     NaN
# 10  Patterns in the skin microbiota differ in chil...                     NaN
# 14                                Flores_forehead_EBI                     NaN
# 16                        Dorrestein_3D_metabolic_map                     NaN
# 18                   Human skin microbiota Metagenome                     NaN
# 21                                                NaN                     NaN
# 22  Longitudinal study of the diabetic skin and wo...                     NaN
# 23  Skin microbiome in human volunteers inoculated...                     NaN
# 24                                                NaN                     NaN
# 26  Impact of the Mk VI SkinSuit on skin microbiot...                     NaN
# 27  Microbiome samples derived from Buruli ulcer w...                     NaN
# 28  Isolation and Identification of the Follicular...                     NaN
# 30                                                NaN                     NaN
# 31                                    Flores_palm_EBI                     NaN
#
#     name  releaseDate_date
# 0    NaN               NaN
# 1    NaN               NaN
# 2    NaN               NaN
# 4    NaN               NaN
# 6    NaN               NaN
# 7    NaN               NaN
# 10   NaN               NaN
# 14   NaN               NaN
# 16   NaN               NaN
# 18   NaN               NaN
# 21   NaN               NaN
# 22   NaN               NaN
# 23   NaN               NaN
# 24   NaN               NaN
# 26   NaN               NaN
# 27   NaN               NaN
# 28   NaN               NaN
# 30   NaN               NaN
# 31   NaN               NaN

# %% [markdown]
# ## Example of downloading one study set <a name="example1"></a>
# Below are example of downloading one study set

# %%
study_accession = 'PRJEB26427'
pipeline_version = '4.1'
fetch_metadata(study_accession)  
stats_downloader(study_accession, pipeline_version)
PRJEB26427_downloadables = read_statistics(study_accession, pipeline_version)

# %%
pd.read_csv('../tables/PRJEB26427/PRJEB26427_sample.csv', index_col=0)
# Out:
#            collection date       environment (biome) environment (feature)  \
# ERR2538349         2015-08  Human-associated habitat        Malodor aspect
# ERR2538350         2015-08  Human-associated habitat        Malodor aspect
# ERR2538351         2015-08  Human-associated habitat        Malodor aspect
# ERR2538352         2015-08  Human-associated habitat        Malodor aspect
# ERR2538353         2015-08  Human-associated habitat        Malodor aspect
# ...                    ...                       ...                   ...
# ERR2538523         2015-08  Human-associated habitat        Malodor aspect
# ERR2538524         2015-08  Human-associated habitat        Malodor aspect
# ERR2538525         2015-08  Human-associated habitat        Malodor aspect
# ERR2538526         2015-08  Human-associated habitat        Malodor aspect
# ERR2538527         2015-08  Human-associated habitat        Malodor aspect
#
#            environment (material) geographic location (country and/or sea)  \
# ERR2538349                   skin                              Philippines
# ERR2538350                   skin                              Philippines
# ERR2538351                   skin                              Philippines
# ERR2538352                   skin                              Philippines
# ERR2538353                   skin                              Philippines
# ...                           ...                                      ...
# ERR2538523                   skin                              Philippines
# ERR2538524                   skin                              Philippines
# ERR2538525                   skin                              Philippines
# ERR2538526                   skin                              Philippines
# ERR2538527                   skin                              Philippines
#
#            geographic location (latitude) geographic location (longitude)  \
# ERR2538349                      14.5995DD                      120.9842DD
# ERR2538350                      14.5995DD                      120.9842DD
# ERR2538351                      14.5995DD                      120.9842DD
# ERR2538352                      14.5995DD                      120.9842DD
# ERR2538353                      14.5995DD                      120.9842DD
# ...                                   ...                             ...
# ERR2538523                      14.5995DD                      120.9842DD
# ERR2538524                      14.5995DD                      120.9842DD
# ERR2538525                      14.5995DD                      120.9842DD
# ERR2538526                      14.5995DD                      120.9842DD
# ERR2538527                      14.5995DD                      120.9842DD
#
#            human skin environmental package investigation type  \
# ERR2538349                       human-skin         metagenome
# ERR2538350                       human-skin         metagenome
# ERR2538351                       human-skin         metagenome
# ERR2538352                       human-skin         metagenome
# ERR2538353                       human-skin         metagenome
# ...                                     ...                ...
# ERR2538523                       human-skin         metagenome
# ERR2538524                       human-skin         metagenome
# ERR2538525                       human-skin         metagenome
# ERR2538526                       human-skin         metagenome
# ERR2538527                       human-skin         metagenome
#
#                                                  project name  \
# ERR2538349  Understanding the microbial basis of body odor...
# ERR2538350  Understanding the microbial basis of body odor...
# ERR2538351  Understanding the microbial basis of body odor...
# ERR2538352  Understanding the microbial basis of body odor...
# ERR2538353  Understanding the microbial basis of body odor...
# ...                                                       ...
# ERR2538523  Understanding the microbial basis of body odor...
# ERR2538524  Understanding the microbial basis of body odor...
# ERR2538525  Understanding the microbial basis of body odor...
# ERR2538526  Understanding the microbial basis of body odor...
# ERR2538527  Understanding the microbial basis of body odor...
#
#            sequencing method ENA-CHECKLIST  ENA-SPOT-COUNT  ENA-BASE-COUNT  \
# ERR2538349    Illumina HiSeq     ERC000017        31417827      3136503308
# ERR2538350    Illumina HiSeq     ERC000017        27827945      2778965519
# ERR2538351    Illumina HiSeq     ERC000017        38533917      3848100187
# ERR2538352    Illumina HiSeq     ERC000017        35959808      3590778644
# ERR2538353    Illumina HiSeq     ERC000017        26637196      2660198624
# ...                      ...           ...             ...             ...
# ERR2538523    Illumina HiSeq     ERC000017        27391255      2732856825
# ERR2538524    Illumina HiSeq     ERC000017        11858320      1181401371
# ERR2538525    Illumina HiSeq     ERC000017        12816015      1277202640
# ERR2538526    Illumina HiSeq     ERC000017        14769354      1473118680
# ERR2538527    Illumina HiSeq     ERC000017        41661717      4155473308
#
#            ENA-FIRST-PUBLIC ENA-LAST-UPDATE      Sample  Read depth
# ERR2538349       2018-05-07      2018-04-26  ERS2431609         NaN
# ERR2538350       2018-05-07      2018-04-26  ERS2431610         NaN
# ERR2538351       2018-05-07      2018-04-26  ERS2431611         NaN
# ERR2538352       2018-05-07      2018-04-26  ERS2431612         NaN
# ERR2538353       2018-05-07      2018-04-26  ERS2431613         NaN
# ...                     ...             ...         ...         ...
# ERR2538523       2018-05-07      2018-04-26  ERS2431783         NaN
# ERR2538524       2018-05-07      2018-04-26  ERS2431784         NaN
# ERR2538525       2018-05-07      2018-04-26  ERS2431785         NaN
# ERR2538526       2018-05-07      2018-04-26  ERS2431786         NaN
# ERR2538527       2018-05-07      2018-04-26  ERS2431787         NaN
#
# [179 rows x 18 columns]

# %%
# emg toolkit bulkdownloader can only download in bulk of what's in the group type of a given study
#downloader(study_accession, '4.1', 'functional_analysis') # FASTQ_InterPro.tsv.gz ~approx 500 mb

# %%
# filter for GO slim annotaion
PRJEB26427_downloadables = read_statistics(study_accession, pipeline_version)
PRJEB26427_downloadables[PRJEB26427_downloadables.description == 'GO slim annotation']
# Out:
#        analysis_id                          name           group_type  \
# 16    MGYA00381356  ERR2538349_FASTQ_GO_slim.csv  Functional analysis
# 56    MGYA00381357  ERR2538350_FASTQ_GO_slim.csv  Functional analysis
# 98    MGYA00381358  ERR2538351_FASTQ_GO_slim.csv  Functional analysis
# 140   MGYA00381359  ERR2538352_FASTQ_GO_slim.csv  Functional analysis
# 181   MGYA00381360  ERR2538353_FASTQ_GO_slim.csv  Functional analysis
# ...            ...                           ...                  ...
# 6682  MGYA00381530  ERR2538523_FASTQ_GO_slim.csv  Functional analysis
# 6715  MGYA00381531  ERR2538524_FASTQ_GO_slim.csv  Functional analysis
# 6747  MGYA00381532  ERR2538525_FASTQ_GO_slim.csv  Functional analysis
# 6782  MGYA00381533  ERR2538526_FASTQ_GO_slim.csv  Functional analysis
# 6824  MGYA00381534  ERR2538527_FASTQ_GO_slim.csv  Functional analysis
#
#              description                                       download_url  \
# 16    GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 56    GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 98    GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 140   GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 181   GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# ...                  ...                                                ...
# 6682  GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6715  GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6747  GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6782  GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
# 6824  GO slim annotation  https://www.ebi.ac.uk/metagenomics/api/v1/anal...
#
#       pipeline_version experiment_type
# 16                 4.1     metagenomic
# 56                 4.1     metagenomic
# 98                 4.1     metagenomic
# 140                4.1     metagenomic
# 181                4.1     metagenomic
# ...                ...             ...
# 6682               4.1     metagenomic
# 6715               4.1     metagenomic
# 6747               4.1     metagenomic
# 6782               4.1     metagenomic
# 6824               4.1     metagenomic
#
# [179 rows x 7 columns]

# %%
# download filtered item
PRJEB26427_goslim = PRJEB26427_downloadables[PRJEB26427_downloadables.description == 'GO slim annotation']
item_downloader(study_accession, PRJEB26427_goslim)

# %% [markdown]
# ## Example of downloading multiple study set <a name="example2"></a>
# Below are example of downloading the first 10 study metadata and its downloadable list

# %%
study_accession = df_studies.loc[:10, 'ENA_PROJECT']
pipeline_version = '4.1'
for i in study_accession:
    print(i)
    fetch_metadata(i)  
    stats_downloader(i, pipeline_version, 'statistics')
    #_downloadables = read_statistics(i)
# Out:
# PRJEB26427
# PRJNA314604
# PRJNA281366
# PRJNA277905
# PRJEB10133
# 0it [00:00, ?it/s]
# WARNING:root:Could not retrieve any results for the given parameters!
# Study Id: PRJEB10133
# Pipeline version: 4.1
#  Download complete!
# PRJEB10295
# 0it [00:00, ?it/s]
# WARNING:root:Could not retrieve any results for the given parameters!
# Study Id: PRJEB10295
# Pipeline version: 4.1
#  Download complete!
# PRJEB14627

# %%
#dict_ = {}
for i in study_accession:
    _downloadables = read_statistics(i, pipeline_version)
    try:
        _downloadables_goslim = _downloadables[_downloadables.description == 'GO slim annotation']
        if _downloadables_goslim.experiment_type.isin(['metagenomic']).any():
            print(i, ': all downloaded')
            #dict_[i] = _downloadables_goslim
            item_downloader(i, _downloadables_goslim)
        else:
            print('Error', i, 'available analysis types :', _downloadables.experiment_type.unique())
    except (AttributeError, TypeError) as e: #, TypeError, AttributeError, 
        print('Error', i, _downloadables)
# Out:
# PRJEB26427 : all downloaded
# Error PRJNA314604 available analysis types : ['amplicon']
# PRJNA281366 : all downloaded
# PRJNA277905 : all downloaded
# Error PRJEB10133 Pipeline version 4.1 is not available
# Error PRJEB10295 Pipeline version 4.1 is not available
# Error PRJEB14627 available analysis types : ['amplicon']
